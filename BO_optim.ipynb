# %%
#Import libraries
import pandas as pd
import numpy as np
from bayes_opt import BayesianOptimization
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
from xgboost import XGBClassifier

# %%
#Bayesian optimization
def bayesian_optimization(dataset, function, parameters):
   X_train, y_train, X_test, y_test = dataset
   n_iterations = 5
   gp_params = {"alpha": 1e-4}

   BO = BayesianOptimization(function, parameters)
   BO.maximize(n_iter=n_iterations, **gp_params)

   return BO.max

# %%
rfBO = BayesianOptimization(rfc_optimization,{'n_estimators': (30,1000), 'max_depth' :(1,150), 'min_samples_split':(2,10)},verbose=True)

# %%
rfBO.maximize(init_points= 32, n_iter=40)
# Out:
# |   iter    |  target   | max_depth | min_sa... | n_esti... |
# -------------------------------------------------------------
# |  2        |  0.9771   |  79.3     |  5.541    |  949.3    |
# |  4        |  0.978    |  65.78    |  3.099    |  865.6    |
# |  13       |  0.978    |  34.23    |  3.664    |  871.7    |
# |  28       |  0.978    |  22.93    |  3.181    |  993.9    |
# |  33       |  0.9782   |  148.7    |  2.025    |  999.0    |
# |  44       |  0.9783   |  75.09    |  2.0      |  519.2    |
# =============================================================

# %%
def xgb_optimization(eta, gamma, max_depth):
    return cross_val_score(
        XGBClassifier(
            objective="binary:logistic",
                       learning_rate=max(eta, 0),
                       gamma=max(gamma, 0),
                       max_depth=int(max_depth),                                               
                       seed=42,
                       nthread=-1,
                       scale_pos_weight = len(y_train[y_train == 'Healthy'])/
                                          len(y_train[y_train == 'Diabetic'])),  
                   X=X_train, 
                   y=y_train, 
                   cv=10,
                   scoring="roc_auc",
                   fit_params={
                        "early_stopping_rounds": 10, 
                        "eval_metric": "auc", 
                        "eval_set": [(X_train,y_train),(X_test,y_test)]},
                   n_jobs=-1).mean()

    parameters = {"eta": eta,
                  "gamma": gamma,
                  "max_depth": max_depth}
    
    return function, parameters

# %%
xgbBO = BayesianOptimization(xgb_optimization,{'eta': (.001,0.4), 'gamma' :(0,20), 'max_depth':(1,2000)},verbose=True)

# %%
xgbBO.maximize(init_points= 32, n_iter=40)
# Out:
# |   iter    |  target   |    eta    |   gamma   | max_depth |
# -------------------------------------------------------------
# |  2        |  0.9278   |  0.022    |  5.114    |  1.927e+0 |
# |  3        |  0.9577   |  0.1936   |  0.8304   |  1.158e+0 |
# |  5        |  0.9585   |  0.3766   |  3.324    |  1.088e+0 |
# |  10       |  0.9669   |  0.3499   |  2.684    |  1.832e+0 |
# |  46       |  0.9678   |  0.369    |  0.05048  |  1.342e+0 |
# |  66       |  0.9687   |  0.3683   |  0.03444  |  1.526e+0 |
# =============================================================

# %%
 len(y_train[y_train == 1])
# Out:
# 0

# %%
y_train
# Out:
# 0        Healthy
# 1        Healthy
# 2        Healthy
# 3        Healthy
# 4        Healthy
# 5        Healthy
# 6        Healthy
# 7        Healthy
# 8        Healthy
# 9        Healthy
# 10       Healthy
# 11       Healthy
# 12       Healthy
# 13       Healthy
# 14       Healthy
# 15       Healthy
# 16       Healthy
# 17       Healthy
# 18       Healthy
# 19       Healthy
# 20       Healthy
# 21       Healthy
# 22       Healthy
# 23       Healthy
# 24       Healthy
# 25       Healthy
# 26       Healthy
# 27       Healthy
# 28       Healthy
# 29       Healthy
#           ...
# 2408    Diabetic
# 2409    Diabetic
# 2410    Diabetic
# 2411    Diabetic
# 2412    Diabetic
# 2413    Diabetic
# 2414    Diabetic
# 2415    Diabetic
# 2416    Diabetic
# 2417    Diabetic
# 2418    Diabetic
# 2419    Diabetic
# 2420    Diabetic
# 2421    Diabetic
# 2422    Diabetic
# 2423    Diabetic
# 2424    Diabetic
# 2425    Diabetic
# 2426    Diabetic
# 2427    Diabetic
# 2428    Diabetic
# 2429    Diabetic
# 2430    Diabetic
# 2431    Diabetic
# 2432    Diabetic
# 2433    Diabetic
# 2434    Diabetic
# 2435    Diabetic
# 2436    Diabetic
# 2437    Diabetic
# Name: Status, Length: 2438, dtype: object

# %%
def rfc_optimization(n_estimators, max_depth, min_samples_split):
    return cross_val_score(
               RandomForestClassifier(
                   n_estimators=int(max(n_estimators,0)),                                                               
                   max_depth=int(max(max_depth,1)),
                   min_samples_split=int(max(min_samples_split,2)), 
                   n_jobs=-1, 
                   random_state=42,   
                   class_weight="balanced"),  
               X=X_train, 
               y=y_train, 
               cv=10,
               scoring="roc_auc",
               n_jobs=-1).mean()

    parameters = {"n_estimators":n_estimators,
                  "max_depth":max_depth,
                  "min_samples_split":min_samples_split}
    
    return function, parameters

# %%
#Train model
def train(X_train, y_train, X_test, y_test, function, parameters):
    dataset = (X_train, y_train, X_test, y_test)
    cv_splits = 4
    
    best_solution = bayesian_optimization(dataset, function, parameters)      
    params = best_solution["params"]

    model = RandomForestClassifier(
             n_estimators=int(),
             max_depth=int()),
             min_samples_split=int()), 
             n_jobs=-1, 
             random_state=42,   
             class_weight="balanced")

    model.fit(X_train, y_train)
    
    return model

# %%
y_pred = model.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-5eb1c495137f> in <module>
# ----> 1 y_pred = model.predict(X_test)
#       2 print(metrics.accuracy_score(y_test, y_pred))
#
# NameError: name 'model' is not defined

# %%
train(X_train,y_train,X_test,y_test,rfc_optimization(10))
# Out:
# |   iter    |  target   | max_fe... | min_sa... | n_esti... |
# -------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (4.638869557198953, 13.197957878716974, 14.377277390071145)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-f408812365ad> in <module>
# ----> 1 train(X_train,y_train,X_test,y_test,rfc_optimization(10))
#
# <ipython-input-65-4a6cfb0d708e> in train(X_train, y_train, X_test, y_test, function)
#       4     cv_splits = 4
#       5
# ----> 6     best_solution = bayesian_optimization(dataset, function)
#       7     params = best_solution["params"]
#       8
#
# <ipython-input-75-f711caeca548> in bayesian_optimization(dataset, function)
#      11             "max_features": (1, 20)
#      12         }, random_state=1234, verbose=2)
# ---> 13    BO.maximize(n_iter=n_iterations, **gp_params)
#      14
#      15    return BO.max
#
# ~\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, xi, **gp_params)
#     172                 iteration += 1
#     173
# --> 174             self.probe(x_probe, lazy=False)
#     175
#     176         self.dispatch(Events.OPTMIZATION_END)
#
# ~\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in probe(self, params, lazy)
#     110             self._queue.add(params)
#     111         else:
# --> 112             self._space.probe(params)
#     113             self.dispatch(Events.OPTMIZATION_STEP)
#     114
#
# ~\Anaconda3\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# TypeError: 'tuple' object is not callable

# %%
train =pd.read_csv('C:/Users/Rick/Desktop/18July_feature_nhanes/train.csv')

# %%
test = pd.read_csv('C:/Users/Rick/Desktop/18July_feature_nhanes/test.csv')

# %%
test = test.drop('Unnamed: 0', axis = 1)

# %%
test.head()
# Out:
#    ridageyr.y  dmdhrage  whd140  WaistCircumference  whq150  whd050  \
# 0          78        79   240.0               116.5      46   212.0
# 1          24        24   130.0                79.5      24   122.0
# 2          66        66   235.0               109.5      65   235.0
# 3          24        24   220.0                89.2      22   200.0
# 4          20        20   130.0                78.4      20   126.0
#
#    BPSystolic   BMI  Weight  paq655  ...  drxtkcal_avg  drxtmfat_avg  \
# 0         132  28.8    83.4       0  ...        2205.0        29.409
# 1         108  25.3    61.8       0  ...        1720.5        25.754
# 2         162  34.0   102.9       0  ...        3104.5        47.438
# 3         124  26.9    89.2       6  ...        2585.0        30.903
# 4         116  22.2    60.4       0  ...         833.0         8.282
#
#    drxtchol_avg  drxtphos_avg  drxtmagn_avg  drxtm181_avg  drxts160_avg  \
# 0         416.0        1437.5         387.0       27.2820       16.3785
# 1         411.0        1349.0         265.5       24.3920       10.6130
# 2         466.0        1526.0         275.5       44.3705       27.0455
# 3         337.0        1237.0         299.0       29.1290       16.0290
# 4         124.0         394.0          98.0        7.5840        4.5030
#
#    drxtchl_avg  drxts180_avg   Status
# 0       514.80        8.2005  Healthy
# 1       415.45        4.0600  Healthy
# 2       561.30       10.8185  Healthy
# 3       312.80        8.1900  Healthy
# 4       133.60        2.5790  Healthy
#
# [5 rows x 23 columns]

# %%
X_test = test.iloc[:,0:22]

# %%
X_test.head()
# Out:
#    ridageyr.y  dmdhrage  whd140  WaistCircumference  whq150  whd050  \
# 0          78        79   240.0               116.5      46   212.0
# 1          24        24   130.0                79.5      24   122.0
# 2          66        66   235.0               109.5      65   235.0
# 3          24        24   220.0                89.2      22   200.0
# 4          20        20   130.0                78.4      20   126.0
#
#    BPSystolic   BMI  Weight  paq655  ...  drxtalco_avg  drxtkcal_avg  \
# 0         132  28.8    83.4       0  ...          0.00        2205.0
# 1         108  25.3    61.8       0  ...          0.00        1720.5
# 2         162  34.0   102.9       0  ...          7.75        3104.5
# 3         124  26.9    89.2       6  ...          0.00        2585.0
# 4         116  22.2    60.4       0  ...          0.00         833.0
#
#    drxtmfat_avg  drxtchol_avg  drxtphos_avg  drxtmagn_avg  drxtm181_avg  \
# 0        29.409         416.0        1437.5         387.0       27.2820
# 1        25.754         411.0        1349.0         265.5       24.3920
# 2        47.438         466.0        1526.0         275.5       44.3705
# 3        30.903         337.0        1237.0         299.0       29.1290
# 4         8.282         124.0         394.0          98.0        7.5840
#
#    drxts160_avg  drxtchl_avg  drxts180_avg
# 0       16.3785       514.80        8.2005
# 1       10.6130       415.45        4.0600
# 2       27.0455       561.30       10.8185
# 3       16.0290       312.80        8.1900
# 4        4.5030       133.60        2.5790
#
# [5 rows x 22 columns]

# %%
y_test = test['Status']

# %%
y_test
# Out:
# 0       Healthy
# 1       Healthy
# 2       Healthy
# 3       Healthy
# 4       Healthy
# 5       Healthy
# 6       Healthy
# 7       Healthy
# 8      Diabetic
# 9       Healthy
# 10      Healthy
# 11     Diabetic
# 12     Diabetic
# 13     Diabetic
# 14      Healthy
# 15      Healthy
# 16      Healthy
# 17      Healthy
# 18      Healthy
# 19     Diabetic
# 20     Diabetic
# 21     Diabetic
# 22      Healthy
# 23      Healthy
# 24      Healthy
# 25      Healthy
# 26      Healthy
# 27      Healthy
# 28      Healthy
# 29      Healthy
#          ...
# 519     Healthy
# 520     Healthy
# 521     Healthy
# 522     Healthy
# 523     Healthy
# 524     Healthy
# 525     Healthy
# 526     Healthy
# 527     Healthy
# 528     Healthy
# 529     Healthy
# 530     Healthy
# 531    Diabetic
# 532     Healthy
# 533     Healthy
# 534     Healthy
# 535     Healthy
# 536    Diabetic
# 537     Healthy
# 538     Healthy
# 539     Healthy
# 540     Healthy
# 541     Healthy
# 542     Healthy
# 543    Diabetic
# 544    Diabetic
# 545     Healthy
# 546     Healthy
# 547     Healthy
# 548     Healthy
# Name: Status, Length: 549, dtype: object

# %%
train = train.drop('Unnamed: 0', axis = 1)

# %%
train.head()
# Out:
#    ridageyr.y  dmdhrage  whd140  WaistCircumference  whq150  whd050  \
# 0        58.0      60.0   185.0                93.0    58.0   180.0
# 1        47.0      45.0   175.0                90.0    45.0   165.0
# 2        68.0      68.0   230.0               101.5    40.0   220.0
# 3        29.0      29.0   165.0                90.5    29.0   150.0
# 4        28.0      28.0   105.0                71.0    18.0   100.0
#
#    BPSystolic   BMI  Weight  paq655  ...  drxtkcal_avg  drxtmfat_avg  \
# 0       140.0  26.6    83.9     1.0  ...        2438.5       32.0570
# 1       128.0  24.8    77.9     0.0  ...        1660.0       16.7055
# 2       144.0  27.0    92.3     0.0  ...        1219.0       32.0270
# 3       110.0  23.8    69.2     5.0  ...        2857.0       24.2720
# 4       108.0  18.4    45.9     3.0  ...        1884.0       25.6160
#
#    drxtchol_avg  drxtphos_avg  drxtmagn_avg  drxtm181_avg  drxts160_avg  \
# 0         381.0        1270.0         281.0        29.412       15.5475
# 1         209.5         891.5         210.0        15.383        7.6060
# 2         207.0         980.0         108.0        29.038       14.8840
# 3         357.0        1393.0         415.0        22.316       11.6550
# 4         409.0        1517.0         316.0        23.655       11.4370
#
#    drxtchl_avg  drxts180_avg   Status
# 0       490.25         8.482  Healthy
# 1       294.20         3.549  Healthy
# 2       199.80         8.532  Healthy
# 3       706.30         4.992  Healthy
# 4       442.60         5.793  Healthy
#
# [5 rows x 23 columns]

# %%
X_train = train.iloc[:,0:22]

# %%
X_train.head()
# Out:
#    ridageyr.y  dmdhrage  whd140  WaistCircumference  whq150  whd050  \
# 0        58.0      60.0   185.0                93.0    58.0   180.0
# 1        47.0      45.0   175.0                90.0    45.0   165.0
# 2        68.0      68.0   230.0               101.5    40.0   220.0
# 3        29.0      29.0   165.0                90.5    29.0   150.0
# 4        28.0      28.0   105.0                71.0    18.0   100.0
#
#    BPSystolic   BMI  Weight  paq655  ...  drxtalco_avg  drxtkcal_avg  \
# 0       140.0  26.6    83.9     1.0  ...          0.00        2438.5
# 1       128.0  24.8    77.9     0.0  ...         44.65        1660.0
# 2       144.0  27.0    92.3     0.0  ...          0.00        1219.0
# 3       110.0  23.8    69.2     5.0  ...        126.30        2857.0
# 4       108.0  18.4    45.9     3.0  ...          0.00        1884.0
#
#    drxtmfat_avg  drxtchol_avg  drxtphos_avg  drxtmagn_avg  drxtm181_avg  \
# 0       32.0570         381.0        1270.0         281.0        29.412
# 1       16.7055         209.5         891.5         210.0        15.383
# 2       32.0270         207.0         980.0         108.0        29.038
# 3       24.2720         357.0        1393.0         415.0        22.316
# 4       25.6160         409.0        1517.0         316.0        23.655
#
#    drxts160_avg  drxtchl_avg  drxts180_avg
# 0       15.5475       490.25         8.482
# 1        7.6060       294.20         3.549
# 2       14.8840       199.80         8.532
# 3       11.6550       706.30         4.992
# 4       11.4370       442.60         5.793
#
# [5 rows x 22 columns]

# %%
y_train.head()
# Out:
#    ridageyr.y  dmdhrage  whd140  WaistCircumference  whq150  whd050  \
# 0        58.0      60.0   185.0                93.0    58.0   180.0
# 1        47.0      45.0   175.0                90.0    45.0   165.0
# 2        68.0      68.0   230.0               101.5    40.0   220.0
# 3        29.0      29.0   165.0                90.5    29.0   150.0
# 4        28.0      28.0   105.0                71.0    18.0   100.0
#
#    BPSystolic   BMI  Weight  paq655  ...  drxtalco_avg  drxtkcal_avg  \
# 0       140.0  26.6    83.9     1.0  ...          0.00        2438.5
# 1       128.0  24.8    77.9     0.0  ...         44.65        1660.0
# 2       144.0  27.0    92.3     0.0  ...          0.00        1219.0
# 3       110.0  23.8    69.2     5.0  ...        126.30        2857.0
# 4       108.0  18.4    45.9     3.0  ...          0.00        1884.0
#
#    drxtmfat_avg  drxtchol_avg  drxtphos_avg  drxtmagn_avg  drxtm181_avg  \
# 0       32.0570         381.0        1270.0         281.0        29.412
# 1       16.7055         209.5         891.5         210.0        15.383
# 2       32.0270         207.0         980.0         108.0        29.038
# 3       24.2720         357.0        1393.0         415.0        22.316
# 4       25.6160         409.0        1517.0         316.0        23.655
#
#    drxts160_avg  drxtchl_avg  drxts180_avg
# 0       15.5475       490.25         8.482
# 1        7.6060       294.20         3.549
# 2       14.8840       199.80         8.532
# 3       11.6550       706.30         4.992
# 4       11.4370       442.60         5.793
#
# [5 rows x 22 columns]

# %%
y_train = train['Status']

# %%
y_train
# Out:
# 0        Healthy
# 1        Healthy
# 2        Healthy
# 3        Healthy
# 4        Healthy
# 5        Healthy
# 6        Healthy
# 7        Healthy
# 8        Healthy
# 9        Healthy
# 10       Healthy
# 11       Healthy
# 12       Healthy
# 13       Healthy
# 14       Healthy
# 15       Healthy
# 16       Healthy
# 17       Healthy
# 18       Healthy
# 19       Healthy
# 20       Healthy
# 21       Healthy
# 22       Healthy
# 23       Healthy
# 24       Healthy
# 25       Healthy
# 26       Healthy
# 27       Healthy
# 28       Healthy
# 29       Healthy
#           ...
# 2408    Diabetic
# 2409    Diabetic
# 2410    Diabetic
# 2411    Diabetic
# 2412    Diabetic
# 2413    Diabetic
# 2414    Diabetic
# 2415    Diabetic
# 2416    Diabetic
# 2417    Diabetic
# 2418    Diabetic
# 2419    Diabetic
# 2420    Diabetic
# 2421    Diabetic
# 2422    Diabetic
# 2423    Diabetic
# 2424    Diabetic
# 2425    Diabetic
# 2426    Diabetic
# 2427    Diabetic
# 2428    Diabetic
# 2429    Diabetic
# 2430    Diabetic
# 2431    Diabetic
# 2432    Diabetic
# 2433    Diabetic
# 2434    Diabetic
# 2435    Diabetic
# 2436    Diabetic
# 2437    Diabetic
# Name: Status, Length: 2438, dtype: object
